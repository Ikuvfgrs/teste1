# %% [markdown]
# <a href="https://colab.research.google.com/github/Ikuvfgrs/teste1/blob/master/C%C3%B3pia_de_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
c = int(input("Digite a temperatura em celsius: "))
f = (c * 9/5) + 32
print("O valor em fahrenheit: ", f)
